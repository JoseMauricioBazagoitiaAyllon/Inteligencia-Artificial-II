# %%
import random
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from PIL import Image, ImageOps
import matplotlib.patches as mpatches
import matplotlib.patheffects as PathEffects
from sklearn.datasets import fetch_openml
from torch.utils.data import DataLoader
# %matplotlib inline
from pycocotools.coco import COCO
import pylab

pylab.rcParams['figure.figsize'] = (8.0, 10.0)# Import Libraries

device = "cuda" if torch.cuda.is_available() else "cpu"

device
# Out:
# 'cuda'

# %% [markdown]
# ###Datos

# %%
# !cp -av "/content/drive/MyDrive/IA2/dataset_basura_deteccion/" "/content/data"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (438).png' -> '/content/data/images/bolsasPlasticas/bolsa (438).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (436).png' -> '/content/data/images/bolsasPlasticas/bolsa (436).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (445).png' -> '/content/data/images/bolsasPlasticas/bolsa (445).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (426).png' -> '/content/data/images/bolsasPlasticas/bolsa (426).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (439).png' -> '/content/data/images/bolsasPlasticas/bolsa (439).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (431).png' -> '/content/data/images/bolsasPlasticas/bolsa (431).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (430).png' -> '/content/data/images/bolsasPlasticas/bolsa (430).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (428).png' -> '/content/data/images/bolsasPlasticas/bolsa (428).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (433).png' -> '/content/data/images/bolsasPlasticas/bolsa (433).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (441).png' -> '/content/data/images/bolsasPlasticas/bolsa (441).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (446).png' -> '/content/data/images/bolsasPlasticas/bolsa (446).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (440).png' -> '/content/data/images/bolsasPlasticas/bolsa (440).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (444).png' -> '/content/data/images/bolsasPlasticas/bolsa (444).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (448).png' -> '/content/data/images/bolsasPlasticas/bolsa (448).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (466).png' -> '/content/data/images/bolsasPlasticas/bolsa (466).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (453).png' -> '/content/data/images/bolsasPlasticas/bolsa (453).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (455).png' -> '/content/data/images/bolsasPlasticas/bolsa (455).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (461).png' -> '/content/data/images/bolsasPlasticas/bolsa (461).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (462).png' -> '/content/data/images/bolsasPlasticas/bolsa (462).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (463).png' -> '/content/data/images/bolsasPlasticas/bolsa (463).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (470).png' -> '/content/data/images/bolsasPlasticas/bolsa (470).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (469).png' -> '/content/data/images/bolsasPlasticas/bolsa (469).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (456).png' -> '/content/data/images/bolsasPlasticas/bolsa (456).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (449).png' -> '/content/data/images/bolsasPlasticas/bolsa (449).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (454).png' -> '/content/data/images/bolsasPlasticas/bolsa (454).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (450).png' -> '/content/data/images/bolsasPlasticas/bolsa (450).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (458).png' -> '/content/data/images/bolsasPlasticas/bolsa (458).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (468).png' -> '/content/data/images/bolsasPlasticas/bolsa (468).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (451).png' -> '/content/data/images/bolsasPlasticas/bolsa (451).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (465).png' -> '/content/data/images/bolsasPlasticas/bolsa (465).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (459).png' -> '/content/data/images/bolsasPlasticas/bolsa (459).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (457).png' -> '/content/data/images/bolsasPlasticas/bolsa (457).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (464).png' -> '/content/data/images/bolsasPlasticas/bolsa (464).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (452).png' -> '/content/data/images/bolsasPlasticas/bolsa (452).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (467).png' -> '/content/data/images/bolsasPlasticas/bolsa (467).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (460).png' -> '/content/data/images/bolsasPlasticas/bolsa (460).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (475).png' -> '/content/data/images/bolsasPlasticas/bolsa (475).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (478).png' -> '/content/data/images/bolsasPlasticas/bolsa (478).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (471).png' -> '/content/data/images/bolsasPlasticas/bolsa (471).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (491).png' -> '/content/data/images/bolsasPlasticas/bolsa (491).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa
png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (716).png' -> '/content/data/images/bolsasPlasticas/bolsa (716).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (712).png' -> '/content/data/images/bolsasPlasticas/bolsa (712).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (722).png' -> '/content/data/images/bolsasPlasticas/bolsa (722).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (718).png' -> '/content/data/images/bolsasPlasticas/bolsa (718).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (710).png' -> '/content/data/images/bolsasPlasticas/bolsa (710).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (719).png' -> '/content/data/images/bolsasPlasticas/bolsa (719).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (709).png' -> '/content/data/images/bolsasPlasticas/bolsa (709).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (707).png' -> '/content/data/images/bolsasPlasticas/bolsa (707).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (713).png' -> '/content/data/images/bolsasPlasticas/bolsa (713).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (721).png' -> '/content/data/images/bolsasPlasticas/bolsa (721).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (734).png' -> '/content/data/images/bolsasPlasticas/bolsa (734).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (735).png' -> '/content/data/images/bolsasPlasticas/bolsa (735).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (725).png' -> '/content/data/images/bolsasPlasticas/bolsa (725).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (739).png' -> '/content/data/images/bolsasPlasticas/bolsa (739).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (730).png' -> '/content/data/images/bolsasPlasticas/bolsa (730).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (729).png' -> '/content/data/images/bolsasPlasticas/bolsa (729).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (727).png' -> '/content/data/images/bolsasPlasticas/bolsa (727).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (728).png' -> '/content/data/images/bolsasPlasticas/bolsa (728).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (731).png' -> '/content/data/images/bolsasPlasticas/bolsa (731).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (733).png' -> '/content/data/images/bolsasPlasticas/bolsa (733).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (736).png' -> '/content/data/images/bolsasPlasticas/bolsa (736).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (740).png' -> '/content/data/images/bolsasPlasticas/bolsa (740).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (726).png' -> '/content/data/images/bolsasPlasticas/bolsa (726).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (732).png' -> '/content/data/images/bolsasPlasticas/bolsa (732).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (738).png' -> '/content/data/images/bolsasPlasticas/bolsa (738).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (737).png' -> '/content/data/images/bolsasPlasticas/bolsa (737).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (746).png' -> '/content/data/images/bolsasPlasticas/bolsa (746).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (751).png' -> '/content/data/images/bolsasPlasticas/bolsa (751).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (752).png' -> '/content/data/images/bolsasPlasticas/bolsa (752).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (745).png' -> '/content/data/images/bolsasPlasticas/bolsa (745).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (744).png' -> '/content/data/images/bolsasPlasticas/bolsa (744).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (755).png' -> '/content/data/images/bolsasPlasticas/bolsa (755).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (753).png' -> '/content/data/images/bolsasPlasticas/bolsa (753).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (756).png' -> '/content/data/images/bolsasPlasticas/bolsa (756).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (754).png' -> '/content/data/images/bolsasPlasticas/bolsa (754).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (757).png' -> '/content/data/images/bolsasPlasticas/bolsa (757).png'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/images/bolsasPlasticas/bolsa (741).png' -> '/content/data/images/bolsasPlasticas/bolsa (741).png'
# ...
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00121.xml' -> '/content/data/labels/EnvasesPlasticos/scene00121.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00004.xml' -> '/content/data/labels/EnvasesPlasticos/scene00004.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00571.xml' -> '/content/data/labels/EnvasesPlasticos/scene00571.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00161.xml' -> '/content/data/labels/EnvasesPlasticos/scene00161.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00848.xml' -> '/content/data/labels/EnvasesPlasticos/scene00848.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00099.xml' -> '/content/data/labels/EnvasesPlasticos/scene00099.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00188.xml' -> '/content/data/labels/EnvasesPlasticos/scene00188.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00695.xml' -> '/content/data/labels/EnvasesPlasticos/scene00695.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00148.xml' -> '/content/data/labels/EnvasesPlasticos/scene00148.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00331.xml' -> '/content/data/labels/EnvasesPlasticos/scene00331.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00709.xml' -> '/content/data/labels/EnvasesPlasticos/scene00709.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00075.xml' -> '/content/data/labels/EnvasesPlasticos/scene00075.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00702.xml' -> '/content/data/labels/EnvasesPlasticos/scene00702.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00629.xml' -> '/content/data/labels/EnvasesPlasticos/scene00629.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00457.xml' -> '/content/data/labels/EnvasesPlasticos/scene00457.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00366.xml' -> '/content/data/labels/EnvasesPlasticos/scene00366.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00581.xml' -> '/content/data/labels/EnvasesPlasticos/scene00581.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00635.xml' -> '/content/data/labels/EnvasesPlasticos/scene00635.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00410.xml' -> '/content/data/labels/EnvasesPlasticos/scene00410.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00663.xml' -> '/content/data/labels/EnvasesPlasticos/scene00663.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00707.xml' -> '/content/data/labels/EnvasesPlasticos/scene00707.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00221.xml' -> '/content/data/labels/EnvasesPlasticos/scene00221.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00013.xml' -> '/content/data/labels/EnvasesPlasticos/scene00013.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00434.xml' -> '/content/data/labels/EnvasesPlasticos/scene00434.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00349.xml' -> '/content/data/labels/EnvasesPlasticos/scene00349.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00802.xml' -> '/content/data/labels/EnvasesPlasticos/scene00802.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00438.xml' -> '/content/data/labels/EnvasesPlasticos/scene00438.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00975.xml' -> '/content/data/labels/EnvasesPlasticos/scene00975.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00655.xml' -> '/content/data/labels/EnvasesPlasticos/scene00655.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00322.xml' -> '/content/data/labels/EnvasesPlasticos/scene00322.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00891.xml' -> '/content/data/labels/EnvasesPlasticos/scene00891.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00765.xml' -> '/content/data/labels/EnvasesPlasticos/scene00765.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00857.xml' -> '/content/data/labels/EnvasesPlasticos/scene00857.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00943(1).xml' -> '/content/data/labels/EnvasesPlasticos/scene00943(1).xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00170.xml' -> '/content/data/labels/EnvasesPlasticos/scene00170.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00980.xml' -> '/content/data/labels/EnvasesPlasticos/scene00980.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00106.xml' -> '/content/data/labels/EnvasesPlasticos/scene00106.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00274.xml' -> '/content/data/labels/EnvasesPlasticos/scene00274.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00947.xml' -> '/content/data/labels/EnvasesPlasticos/scene00947.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00468.xml' -> '/content/data/labels/EnvasesPlasticos/scene00468.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00873.xml' -> '/content/data/labels/EnvasesPlasticos/scene00873.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00402.xml' -> '/content/data/labels/EnvasesPlasticos/scene00402.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00472.xml' -> '/content/data/labels/EnvasesPlasticos/scene00472.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00523.xml' -> '/content/data/labels/EnvasesPlasticos/scene00523.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00589.xml' -> '/content/data/labels/EnvasesPlasticos/scene00589.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00463.xml' -> '/content/data/labels/EnvasesPlasticos/scene00463.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00039.xml' -> '/content/data/labels/EnvasesPlasticos/scene00039.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00658.xml' -> '/content/data/labels/EnvasesPlasticos/scene00658.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00026.xml' -> '/content/data/labels/EnvasesPlasticos/scene00026.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00129.xml' -> '/content/data/labels/EnvasesPlasticos/scene00129.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00791.xml' -> '/content/data/labels/EnvasesPlasticos/scene00791.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00086.xml' -> '/content/data/labels/EnvasesPlasticos/scene00086.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00828.xml' -> '/content/data/labels/EnvasesPlasticos/scene00828.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00510.xml' -> '/content/data/labels/EnvasesPlasticos/scene00510.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00277.xml' -> '/content/data/labels/EnvasesPlasticos/scene00277.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00057.xml' -> '/content/data/labels/EnvasesPlasticos/scene00057.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00015.xml' -> '/content/data/labels/EnvasesPlasticos/scene00015.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00938.xml' -> '/content/data/labels/EnvasesPlasticos/scene00938.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00584.xml' -> '/content/data/labels/EnvasesPlasticos/scene00584.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00197.xml' -> '/content/data/labels/EnvasesPlasticos/scene00197.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00760.xml' -> '/content/data/labels/EnvasesPlasticos/scene00760.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00683.xml' -> '/content/data/labels/EnvasesPlasticos/scene00683.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00799.xml' -> '/content/data/labels/EnvasesPlasticos/scene00799.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00514.xml' -> '/content/data/labels/EnvasesPlasticos/scene00514.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00859.xml' -> '/content/data/labels/EnvasesPlasticos/scene00859.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00867.xml' -> '/content/data/labels/EnvasesPlasticos/scene00867.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00146.xml' -> '/content/data/labels/EnvasesPlasticos/scene00146.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00611.xml' -> '/content/data/labels/EnvasesPlasticos/scene00611.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00941.xml' -> '/content/data/labels/EnvasesPlasticos/scene00941.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00276.xml' -> '/content/data/labels/EnvasesPlasticos/scene00276.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00363.xml' -> '/content/data/labels/EnvasesPlasticos/scene00363.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00477.xml' -> '/content/data/labels/EnvasesPlasticos/scene00477.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00546.xml' -> '/content/data/labels/EnvasesPlasticos/scene00546.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00245.xml' -> '/content/data/labels/EnvasesPlasticos/scene00245.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00610.xml' -> '/content/data/labels/EnvasesPlasticos/scene00610.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00159.xml' -> '/content/data/labels/EnvasesPlasticos/scene00159.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00818.xml' -> '/content/data/labels/EnvasesPlasticos/scene00818.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00876.xml' -> '/content/data/labels/EnvasesPlasticos/scene00876.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00500.xml' -> '/content/data/labels/EnvasesPlasticos/scene00500.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00689.xml' -> '/content/data/labels/EnvasesPlasticos/scene00689.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00224.xml' -> '/content/data/labels/EnvasesPlasticos/scene00224.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00734.xml' -> '/content/data/labels/EnvasesPlasticos/scene00734.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00267.xml' -> '/content/data/labels/EnvasesPlasticos/scene00267.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00623.xml' -> '/content/data/labels/EnvasesPlasticos/scene00623.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00412.xml' -> '/content/data/labels/EnvasesPlasticos/scene00412.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00962.xml' -> '/content/data/labels/EnvasesPlasticos/scene00962.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00309.xml' -> '/content/data/labels/EnvasesPlasticos/scene00309.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00710.xml' -> '/content/data/labels/EnvasesPlasticos/scene00710.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00621.xml' -> '/content/data/labels/EnvasesPlasticos/scene00621.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00542.xml' -> '/content/data/labels/EnvasesPlasticos/scene00542.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00368.xml' -> '/content/data/labels/EnvasesPlasticos/scene00368.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00561.xml' -> '/content/data/labels/EnvasesPlasticos/scene00561.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00743.xml' -> '/content/data/labels/EnvasesPlasticos/scene00743.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00659.xml' -> '/content/data/labels/EnvasesPlasticos/scene00659.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00839.xml' -> '/content/data/labels/EnvasesPlasticos/scene00839.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00917.xml' -> '/content/data/labels/EnvasesPlasticos/scene00917.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00786.xml' -> '/content/data/labels/EnvasesPlasticos/scene00786.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00072.xml' -> '/content/data/labels/EnvasesPlasticos/scene00072.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00739.xml' -> '/content/data/labels/EnvasesPlasticos/scene00739.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00294.xml' -> '/content/data/labels/EnvasesPlasticos/scene00294.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00986.xml' -> '/content/data/labels/EnvasesPlasticos/scene00986.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00340.xml' -> '/content/data/labels/EnvasesPlasticos/scene00340.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00971.xml' -> '/content/data/labels/EnvasesPlasticos/scene00971.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00176.xml' -> '/content/data/labels/EnvasesPlasticos/scene00176.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/scene00001.xml' -> '/content/data/labels/EnvasesPlasticos/scene00001.xml'
# '/content/drive/MyDrive/IA2/dataset_basura_deteccion/labels/EnvasesPlasticos/Yolo' -> '/content/data/labels/EnvasesPlasticos/Yolo'

# %%
import json
cocofile= open("/content/data/labels/plastoformos/polygon/COCO.json")
plastoformos = json.load(cocofile)

# %%
plastoformos['categories'][0],plastoformos['images'][0], plastoformos['annotations'][0]
# Out:
# ({'id': 1, 'name': 'plastoformo'},
#  {'file_name': 'platoformo (1).png', 'height': 600, 'id': 1, 'width': 800},
#  {'area': 217977.34375,
#   'bbox': [267.5, 136.25, 531.25, 463.75],
#   'category_id': 1,
#   'id': 0,
#   'image_id': 1,
#   'iscrowd': 0,
#   'segmentation': [[796.25,
#     141.25,
#     358.75,
#     136.25,
#     337.5,
#     147.5,
#     315,
#     166.25,
#     297.5,
#     208.75,
#     297.5,
#     246.25,
#     296.25,
#     290,
#     286.25,
#     332.5,
#     273.75,
#     382.5,
#     267.5,
#     435,
#     268.75,
#     476.25,
#     277.5,
#     488.75,
#     298.75,
#     515,
#     312.5,
#     525,
#     336.25,
#     533.75,
#     380,
#     548.75,
#     411.25,
#     556.25,
#     451.25,
#     556.25,
#     505,
#     563.75,
#     548.75,
#     565,
#     606.25,
#     570,
#     632.5,
#     575,
#     650,
#     586.25,
#     671.25,
#     597.5,
#     798.75,
#     600]]})

# %%
image_id=10
coco_data=COCO("/content/data/labels/plastoformos/polygon/COCO.json")
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!

# %%
img = coco_data.imgs[image_id]
img
# Out:
# {'file_name': 'platoformo (1006).png', 'height': 600, 'id': 10, 'width': 800}

# %%
image = np.array(Image.open("/content/data/images/Plastoformos/"+img['file_name']).convert('RGB'))
plt.imshow(image, interpolation='nearest')
plt.show()

# %%
plt.imshow(image)
cat_ids = coco_data.getCatIds()
anns_ids = coco_data.getAnnIds(imgIds=img['id'], catIds=cat_ids, iscrowd=None)
anns = coco_data.loadAnns(anns_ids)
coco_data.showAnns(anns,draw_bbox=True)

# %%
mask = coco_data.annToMask(anns[0])
for i in range(len(anns)):
    mask += coco_data.annToMask(anns[i])

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30,10))

ax1.imshow(image)
ax2.imshow(mask)
ax3.imshow(image)
ax3.imshow(mask, alpha=0.4)
plt.show()
#plt.imshow(mask)

# %%
image.shape
# Out:
# (600, 800, 3)

# %%
mask = coco_data.annToMask(anns[0])
mask.shape, image.max()
# Out:
# ((600, 800), 255)

# %%
from random import sample
def loadImages(dataset_coco, split=0.1):
    img_test_ = []
    img_train_ = []
    labels_test_ = []
    labels_train_ = []
    data_ = dataset_coco.anns
    test_ids = sample([x for x in range(0,len(coco_data.anns))],int(len(coco_data.anns)*split))
    for i in data_:
        image_id_ = data_[i]['image_id']
        img_ = coco_data.imgs[image_id_]
        image_path="/content/data/images/Plastoformos/"+img_['file_name']
        image_load_ = Image.open(image_path).convert('RGB')
        image_ = np.array(image_load_)/255
        anns_=dataset_coco.loadAnns(data_[i]['id'])
        mask_ = dataset_coco.annToMask(anns_[0])
        for ian in range(len(anns_)):
            mask_ += dataset_coco.annToMask(anns_[ian])
        if(i not in test_ids):
            img_train_.append(image_path)
            labels_train_.append(mask_)
        else:
            img_test_.append(image_path)
            labels_test_.append(mask_)
    return np.array(img_train_), np.array(img_test_), np.array(labels_train_), np.array(labels_test_)

# %%
img_train, img_test, labels_train, labels_test = loadImages(coco_data, split=0.1)

# %%
labels_train.shape, labels_test.shape, labels_test.min(), labels_test.max()
# Out:
# ((1303, 600, 800), (144, 600, 800), 0, 2)

# %%
class Dataset(torch.utils.data.Dataset):
  def __init__(self, X, y, n_classes=3):
    self.X = X
    self.y = y
    self.n_classes = n_classes

  def __len__(self):
    return len(self.X)

  def __getitem__(self, ix):
      image_load = Image.open(self.X[ix]).convert('RGB')
      image = np.array(image_load)/255
      img = image.astype(np.float32)

      mask = self.y[ix]    
      img = torch.from_numpy(img).permute(2,0,1)
      mask = (np.arange(self.n_classes) == mask[...,None]).astype(np.float32)
      return img, torch.from_numpy(mask).permute(2,0,1)

# %%
dataset = {
    'train': Dataset(img_train, labels_train),
    'test': Dataset(img_test, labels_test)
}

len(dataset['train']), len(dataset['test'])
# Out:
# (1303, 144)

# %%
dataloader = {
    'train': torch.utils.data.DataLoader(dataset['train'], batch_size=5, shuffle=True, pin_memory=True),
    'test': torch.utils.data.DataLoader(dataset['test'], batch_size=10, pin_memory=True)
}

imgs, masks = next(iter(dataloader['train']))
imgs.shape, masks.shape
# Out:
# (torch.Size([5, 3, 600, 800]), torch.Size([5, 3, 600, 800]))

# %%
import torch.nn.functional as F

def conv3x3_bn(ci, co):
    return torch.nn.Sequential(
        torch.nn.Conv2d(ci, co, 3, padding=1),
        torch.nn.BatchNorm2d(co),
        torch.nn.ReLU(inplace=True)
    )

def encoder_conv(ci, co):
  return torch.nn.Sequential(
        torch.nn.MaxPool2d(2),
        conv3x3_bn(ci, co),
        conv3x3_bn(co, co),
    )

class deconv(torch.nn.Module):
    def __init__(self, ci, co):
        super(deconv, self).__init__()
        self.upsample = torch.nn.ConvTranspose2d(ci, co, 2, stride=2)
        self.conv1 = conv3x3_bn(ci, co)
        self.conv2 = conv3x3_bn(co, co)
    
    # recibe la salida de la capa anetrior y la salida de la etapa
    # correspondiente del encoder
    def forward(self, x1, x2):
        x1 = self.upsample(x1)
        diffX = x2.size()[2] - x1.size()[2]
        diffY = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, (diffX, 0, diffY, 0))
        # concatenamos los tensores
        x = torch.cat([x2, x1], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x

class UNet(torch.nn.Module):
    def __init__(self, n_classes=3, in_ch=3):
        super().__init__()

        # lista de capas en encoder-decoder con número de filtros
        c = [16, 32, 64, 128]

        # primera capa conv que recibe la imagen
        self.conv1 = torch.nn.Sequential(
          conv3x3_bn(in_ch, c[0]),
          conv3x3_bn(c[0], c[0]),
        )
        # capas del encoder
        self.conv2 = encoder_conv(c[0], c[1])
        self.conv3 = encoder_conv(c[1], c[2])
        self.conv4 = encoder_conv(c[2], c[3])

        # capas del decoder
        self.deconv1 = deconv(c[3],c[2])
        self.deconv2 = deconv(c[2],c[1])
        self.deconv3 = deconv(c[1],c[0])

        # útlima capa conv que nos da la máscara
        self.out = torch.nn.Conv2d(c[0], n_classes, 3, padding=1)

    def forward(self, x):
        # encoder
        x1 = self.conv1(x)
        x2 = self.conv2(x1)
        x3 = self.conv3(x2)
        x = self.conv4(x3)
        # decoder
        x = self.deconv1(x, x3)
        x = self.deconv2(x, x2)
        x = self.deconv3(x, x1)
        x = self.out(x)
        return x

# %%
model = UNet()
output = model(torch.randn((5,3,600,800)))
output.shape
# Out:
# torch.Size([5, 3, 600, 800])

# %%
def iou(outputs, labels):
    # aplicar sigmoid y convertir a binario
    outputs, labels = torch.sigmoid(outputs) > 0.5, labels > 0.5
    SMOOTH = 1e-6
    # BATCH x num_classes x H x W
    B, N, H, W = outputs.shape
    ious = []
    for i in range(N-1): # saltamos el background
        _out, _labs = outputs[:,i,:,:], labels[:,i,:,:]
        intersection = (_out & _labs).float().sum((1, 2))  
        union = (_out | _labs).float().sum((1, 2))         
        iou = (intersection + SMOOTH) / (union + SMOOTH)  
        ious.append(iou.mean().item())
    return np.mean(ious)

# %%
from tqdm import tqdm

def fit(model, dataloader, epochs=100, lr=3e-4):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = torch.nn.BCEWithLogitsLoss()
    model.to(device)
    hist = {'loss': [], 'iou': [], 'test_loss': [], 'test_iou': []}
    for epoch in range(1, epochs+1):
      bar = tqdm(dataloader['train'])
      train_loss, train_iou = [], []
      model.train()
      for imgs, masks in bar:
        imgs, masks = imgs.to(device), masks.to(device)
        optimizer.zero_grad()
        y_hat = model(imgs)
        loss = criterion(y_hat, masks)
        loss.backward()
        optimizer.step()
        ious = iou(y_hat, masks)
        train_loss.append(loss.item())
        train_iou.append(ious)
        bar.set_description(f"loss {np.mean(train_loss):.5f} iou {np.mean(train_iou):.5f}")
      hist['loss'].append(np.mean(train_loss))
      hist['iou'].append(np.mean(train_iou))
      bar = tqdm(dataloader['test'])
      test_loss, test_iou = [], []
      model.eval()
      with torch.no_grad():
        for imgs, masks in bar:
          imgs, masks = imgs.to(device), masks.to(device)
          y_hat = model(imgs)
          loss = criterion(y_hat, masks)
          ious = iou(y_hat, masks)
          test_loss.append(loss.item())
          test_iou.append(ious)
          bar.set_description(f"test_loss {np.mean(test_loss):.5f} test_iou {np.mean(test_iou):.5f}")
      hist['test_loss'].append(np.mean(test_loss))
      hist['test_iou'].append(np.mean(test_iou))
      print(f"\nEpoch {epoch}/{epochs} loss {np.mean(train_loss):.5f} iou {np.mean(train_iou):.5f} test_loss {np.mean(test_loss):.5f} test_iou {np.mean(test_iou):.5f}")
    return hist

# %%
model = UNet()
hist = fit(model, dataloader, epochs=20)
# Out:
# loss 0.36409 iou 0.71758: 100%|██████████| 261/261 [02:23<00:00,  1.82it/s]
# test_loss 0.51140 test_iou 0.73338: 100%|██████████| 15/15 [00:07<00:00,  1.93it/s]
# Epoch 1/20 loss 0.36409 iou 0.71758 test_loss 0.51140 test_iou 0.73338
# loss 0.26596 iou 0.87783: 100%|██████████| 261/261 [02:19<00:00,  1.87it/s]
# test_loss 0.25090 test_iou 0.89696: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# Epoch 2/20 loss 0.26596 iou 0.87783 test_loss 0.25090 test_iou 0.89696
# loss 0.23865 iou 0.89139: 100%|██████████| 261/261 [02:19<00:00,  1.87it/s]
# test_loss 0.20757 test_iou 0.90815: 100%|██████████| 15/15 [00:07<00:00,  2.02it/
# Epoch 13/20 loss 0.17088 iou 0.92711 test_loss 0.21847 test_iou 0.90527
# loss 0.16585 iou 0.92856: 100%|██████████| 261/261 [02:20<00:00,  1.85it/s]
# test_loss 0.32008 test_iou 0.77458: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# Epoch 14/20 loss 0.16585 iou 0.92856 test_loss 0.32008 test_iou 0.77458
# loss 0.16293 iou 0.93047: 100%|██████████| 261/261 [02:19<00:00,  1.87it/s]
# test_loss 0.19339 test_iou 0.91827: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# Epoch 15/20 loss 0.16293 iou 0.93047 test_loss 0.19339 test_iou 0.91827
# loss 0.16070 iou 0.93116: 100%|██████████| 261/261 [02:19<00:00,  1.87it/s]
# test_loss 0.65365 test_iou 0.74421: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# Epoch 16/20 loss 0.16070 iou 0.93116 test_loss 0.65365 test_iou 0.74421
# loss 0.15607 iou 0.93285: 100%|██████████| 261/261 [02:20<00:00,  1.86it/s]
# test_loss 0.14036 test_iou 0.93881: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# Epoch 17/20 loss 0.15607 iou 0.93285 test_loss 0.14036 test_iou 0.93881
# loss 0.15451 iou 0.93331: 100%|██████████| 261/261 [02:20<00:00,  1.85it/s]
# test_loss 0.25747 test_iou 0.89628: 100%|██████████| 15/15 [00:07<00:00,  2.01it/s]
# Epoch 18/20 loss 0.15451 iou 0.93331 test_loss 0.25747 test_iou 0.89628
# loss 0.15253 iou 0.93377: 100%|██████████| 261/261 [02:20<00:00,  1.86it/s]
# test_loss 0.22258 test_iou 0.91279: 100%|██████████| 15/15 [00:07<00:00,  1.99it/s]
# Epoch 19/20 loss 0.15253 iou 0.93377 test_loss 0.22258 test_iou 0.91279
# loss 0.15010 iou 0.93480: 100%|██████████| 261/261 [02:19<00:00,  1.87it/s]
# test_loss 0.65247 test_iou 0.74204: 100%|██████████| 15/15 [00:07<00:00,  2.00it/s]
# Epoch 20/20 loss 0.15010 iou 0.93480 test_loss 0.65247 test_iou 0.74204

# %%
import random

model.eval()
with torch.no_grad():
    ix = random.randint(0, len(dataset['test'])-1)
    img, mask = dataset['test'][ix]
    
    output = model(img.unsqueeze(0).to(device))[0]
    pred_mask = torch.argmax(output, axis=0)
    
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30,10))
ax1.imshow(img.squeeze(0).permute(1,2,0))
ax2.imshow(torch.argmax(mask, axis=0))

ax3.imshow(img.squeeze(0).permute(1,2,0))
ax3.imshow(pred_mask.squeeze().cpu().numpy(), alpha=0.4)

plt.show()

# %%
image_load_1 = Image.open('/content/descarga (1).jfif.png').convert('RGB')
image_1 = np.array(image_load_1)/255
img_1 = image_1.astype(np.float32)
img_1 = torch.from_numpy(img_1).permute(2,0,1)

# %%
model.eval()
with torch.no_grad():
    output = model(img_1.unsqueeze(0).to(device))[0]
    pred_mask = torch.argmax(output, axis=0)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30,10))
ax1.imshow(img_1.squeeze(0).permute(1,2,0))
ax2.imshow(image_1)

ax3.imshow(img_1.squeeze(0).permute(1,2,0))
ax3.imshow(pred_mask.squeeze().cpu().numpy(), alpha=0.4)
